# %% [markdown]
# <a href="https://colab.research.google.com/github/nmb193-pixel/BTE320-E/blob/main/In_Class_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter Sales: "))
cogs = sales * 0.40
gross_profit = sales - cogs
tax_rate = float(input("Enter Tax Rate (%): "))
tax_amount = gross_profit * (tax_rate / 100)
net_profit = gross_profit - tax_amount
print(f"Net Sales: ${sales}")
print(f"Cost of Goods Sold: ${cogs}")
print(f"Gross Profit: ${gross_profit}")
print(f"Tax Amount: ${tax_amount}")
print(f"Net Profit: ${net_profit}")
# Out:
# Enter Sales: 12000
# Enter Tax Rate (%): 30
# Net Sales: $12000.0
# Cost of Goods Sold: $4800.0
# Gross Profit: $7200.0
# Tax Amount: $2160.0
# Net Profit: $5040.0
