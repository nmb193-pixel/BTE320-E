# %% [markdown]
# <a href="https://colab.research.google.com/github/nmb193-pixel/BTE320-E/blob/main/In_class_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Get inputs from the user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

# Perform calculation using conditionals
if operator == "+":
    result = num1 + num2
elif operator == "-":
    result = num1 - num2
elif operator == "*":
    result = num1 * num2
elif operator == "/":
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error: Division by zero"
else:
    result = "Invalid operator"

# Print result
print("Result:", result)
# Out:
# Enter first number: 59
# Enter second number: 20
# Enter operator (+, -, *, /): +
# Result: 79.0
